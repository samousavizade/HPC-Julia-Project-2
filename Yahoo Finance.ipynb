# %%
import numpy as np
import pandas as pd
#from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
# !pip3 install yfinance
# Out:
# /bin/bash: /home/ahur4/anaconda3/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Requirement already satisfied: yfinance in /home/ahur4/anaconda3/envs/data_env/lib/python3.10/site-packages (0.1.70)
# Requirement already satisfied: multitasking>=0.0.7 in /home/ahur4/anaconda3/envs/data_env/lib/python3.10/site-packages (from yfinance) (0.0.10)
# Requirement already satisfied: requests>=2.26 in /home/ahur4/anaconda3/envs/data_env/lib/python3.10/site-packages (from yfinance) (2.27.1)
# Requirement already satisfied: lxml>=4.5.1 in /home/ahur4/anaconda3/envs/data_env/lib/python3.10/site-packages (from yfinance) (4.8.0)
# Requirement already satisfied: numpy>=1.15 in /home/ahur4/anaconda3/envs/data_env/lib/python3.10/site-packages (from yfinance) (1.22.3)
# Requirement already satisfied: pandas>=0.24.0 in /home/ahur4/anaconda3/envs/data_env/lib/python3.10/site-packages (from yfinance) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/ahur4/anaconda3/envs/data_env/lib/python3.10/site-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ahur4/anaconda3/envs/data_env/lib/python3.10/site-packages (from pandas>=0.24.0->yfinance) (2022.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ahur4/anaconda3/envs/data_env/lib/python3.10/site-packages (from requests>=2.26->yfinance) (2022.5.18.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/ahur4/anaconda3/envs/data_env/lib/python3.10/site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ahur4/anaconda3/envs/data_env/lib/python3.10/site-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ahur4/anaconda3/envs/data_env/lib/python3.10/site-packages (from requests>=2.26->yfinance) (1.26.9)
# Requirement already satisfied: six>=1.5 in /home/ahur4/anaconda3/envs/data_env/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas>=0.24.0->yfinance) (1.16.0)

# %%
import yfinance as yf
data = pd.DataFrame()
# define the ticker symbol
symbols = ["BTC-USD", 
           "ETH-USD",
           "XRP-USD",
           "SOL-USD",
           "LUNA1-USD",
           "ADA-USD",
           "AVA-USD", 
           "DOT-USD",
           "DOGE-USD",
           "MATIC-USD"
           ]

for symbol in symbols:
    #get data on this ticker
    tickerData = yf.Ticker(symbol)
    #get the historical prices for this ticker
    symbol_close_data = tickerData.history(period="1d", start="2021-1-1", end="2022-01-01")["Close"]
    data[symbol] = symbol_close_data

data
# Out:
#                  BTC-USD      ETH-USD   XRP-USD     SOL-USD  LUNA1-USD  \
# Date
# 2021-01-01  29374.152344   730.367554  0.237444    1.842084   0.649443
# 2021-01-02  32127.267578   774.534973  0.221655    1.799275   0.631426
# 2021-01-03  32782.023438   975.507690  0.225848    2.161752   0.661895
# 2021-01-04  31971.914062  1040.233032  0.236677    2.485097   0.670244
# 2021-01-05  33992.429688  1100.006104  0.226750    2.157217   0.716674
# ...                  ...          ...       ...         ...        ...
# 2021-12-28  47588.855469  3800.893066  0.852960  177.425629  85.368347
# 2021-12-29  46444.710938  3628.531738  0.816714  170.657562  84.059334
# 2021-12-30  47178.125000  3713.852051  0.839649  172.751190  84.711868
# 2021-12-31  46306.445312  3682.632812  0.831163  170.299072  85.472542
# 2022-01-01  47686.812500  3769.697021  0.849472  178.517944  91.360588
#
#              ADA-USD   AVA-USD    DOT-USD  DOGE-USD  MATIC-USD
# Date
# 2021-01-01  0.175350  0.794505   8.306819  0.005685   0.017812
# 2021-01-02  0.177423  0.761348   9.208837  0.010615   0.019043
# 2021-01-03  0.204995  0.760217  10.033283  0.009771   0.019975
# 2021-01-04  0.224762  0.818082   9.469611  0.009767   0.024614
# 2021-01-05  0.258314  0.887216   9.701656  0.009920   0.024467
# ...              ...       ...        ...       ...        ...
# 2021-12-28  1.402264  1.922592  27.907103  0.174117   2.498206
# 2021-12-29  1.330814  1.881843  26.744373  0.167765   2.470006
# 2021-12-30  1.360415  1.839795  27.567789  0.171313   2.557751
# 2021-12-31  1.310209  1.853352  26.719675  0.170496   2.527107
# 2022-01-01  1.376975  1.861207  28.583582  0.173035   2.574791
#
# [366 rows x 10 columns]

# %%
data.to_csv("crypto_data.csv")
